# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <b>Арслан, привет!</b>
#
# Меня зовут Полина Бережная, и я буду делать ревью проекта по исследовательскому анализу данных. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
#
# Твой проект просто 🔥🔥🔥. Мне было очень приятно проверять твой проект, так как чувствуется твое старание и желание сделать задание на достойном уровне. Однако есть некоторые аспекты, которые требуют твоего внимания и доработки.
#
# В тетрадке ты можешь встретить 4 вида моих комментариев:
# - <div class="alert alert-danger">
#
#   **Комментарий ревьюера**
#
#     Такой нюанс требует обязательной доработки, иначе проект не будет принят.
#   </div>
#
#
# - <div class="alert alert-warning">
#
#     **Комментарий ревьюера**
#
#     Так выделены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта и выполнении будущих заданий. На твое усмотрение. Однако если в работе больше двух таких комментариев, необходимо их проработать.
#   </div>
#
#
# - <div class="alert alert-success">
#
#   **Комментарий ревьюера**
#
#     Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах.
#   </div>
#
#
# - <div style="border:solid black 2px; padding: 20px">
#
#     **Чек-лист доработок**
#
#     Такой комментарий будет находиться в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательной корректировки.
#   </div>
#
# Предлагаю работать над проектом в форме диалога: если ты **что-то меняешь** в работе по моим рекомендациям — **пиши об этом** и помечай комментарий каким-то заметным цветом. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Не переживай, если что-то не получилось сделать идеально с первого раза. Основная цель нашей команды — не найти ошибки, а поделиться своим опытом и помочь тебе стать профи в аналитике 🙂
#
# Жду твой проект на повторное ревью, ты уже почти на финише!
#
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет еще раз!</b>
#
# Ты отлично поработал, я бы сказал на все 200%! Проект принят, ты большой молодец!
#
# Желаю тебе успехов во всех будущих начинаниях!

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <h1>Содержание проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Исследование-объявлений-о-продаже-квартир-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Исследование объявлений о продаже квартир</a></span><ul class="toc-item"><li><span><a href="#Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию." data-toc-modified-id="Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Шаг 1. Откройте файл с данными и изучите общую информацию.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Шаг 2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Работа с пропусками</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Шаг-3.-Посчитайте-и-добавьте-в-таблицу" data-toc-modified-id="Шаг-3.-Посчитайте-и-добавьте-в-таблицу-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Шаг 3. Посчитайте и добавьте в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой" data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-4.-Проведите-исследовательский-анализ-данных-и-выполните-инструкции:" data-toc-modified-id="Шаг-4.-Проведите-исследовательский-анализ-данных-и-выполните-инструкции:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Шаг 4. Проведите исследовательский анализ данных и выполните инструкции:</a></span><ul class="toc-item"><li><span><a href="#Задание-1" data-toc-modified-id="Задание-1-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Задание 1</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Задание-2" data-toc-modified-id="Задание-2-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Задание 2</a></span></li><li><span><a href="#Задание-3" data-toc-modified-id="Задание-3-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Задание 3</a></span></li><li><span><a href="#Задание-4" data-toc-modified-id="Задание-4-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Задание 4</a></span></li><li><span><a href="#Задание-5" data-toc-modified-id="Задание-5-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Задание 5</a></span></li><li><span><a href="#Задание-6" data-toc-modified-id="Задание-6-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Задание 6</a></span></li><li><span><a href="#Задание-7" data-toc-modified-id="Задание-7-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>Задание 7</a></span></li></ul></li><li><span><a href="#Шаг-5.-Общий-вывод" data-toc-modified-id="Шаг-5.-Общий-вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Шаг 5. Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span><ul class="toc-item"><li><span><a href="#Чек-лист-доработок-" data-toc-modified-id="Чек-лист-доработок--1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Чек-лист доработок </a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ✍️ <b>Описание данных</b>

# %% [markdown]
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах(м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Здорово, что перед кодом есть название проекта и описание задач. Да и все оформление тетрадки выполнено на достойном уровне 👍🏻
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьюера**
#
# Однако предлагаю обратить внимание на несколько нюансов:
# - Стоит добавить план твоих действий и описание данных во введение к работе.
# - Будет здорово, если во введении будет присутствовать навигация по проекту. Можешь, например, использовать гиперссылки для каждого пункта плана.
#
# Данные корректировки сделают твою тетрадку очень удобной для использования другими людьми. Она будет рассказывать историю за тебя и показывать как твои кодинговые навыки, так и умение анализировать и преподносить информацию 🙂
# </div>

# %% [markdown]
# 👋Полина, привет! Спасибо, добавил навигацию и описание данных :)

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Отлично 👍🏻
# </div>

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# В базе встречается три типа данных: целочисленные, дробные, булевы и строки. Уже заранее понятно, что многие дробные значения нужно будет приветси к целочисленным, а столбец first_day_exposition должен содержать дату.
#
# В целом по данным есть очень много пропусков. Есть столбцы, где всего 9 тыс. значений из почти 24 тыс. строк. Эти пропуски нужно будет заполнить

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Ты отлично владеешь методами первичного изучения данных 👍🏻
#
# Стоит также делать проверку на дубликаты.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Работа с пропусками

# %% [markdown]
# По указанию куратора не будем "слишком углубляться в предобработку". Основную часть пропусков, где уместно, заменим на медианное (устойчивое к выбросам) значение.

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В даннх действительно много пропусков.
# 1. Многие из них можно объяснить тем, что значения заполнялись автоматически.
# 2. Другие (balcony, is_apartment) могут означать отсутствие признака
# 3. living_area может быть пропущено потому, что его не посчитали нужным заполнять, введя данные о площаде кухни
# 4. Наиболее подозрительными считаются пропуски в days_exposition, потому что за заполнение этого параметра отвечает непосредственно система

# %% [markdown]
# Столбцы с пропусками:
# * ceiling_height -- важный параметр
# * floors_total -- пропусков мало, можно удалить наблюдения
# * living_area -- попробуем восстановить через общую площадь
# * is_apartment -- вероятно, пропуски означают, что это не апартаменты
# * kitchen_area -- попробуем заполнить через жилую и общую площади
# * balcony -- вероятно, пропуски означают отсутствие балкона
# * locality_name -- название населенного пункта восстановить невозможно
# * airports_nearest
# * cityCenters_nearest
# * parks_around3000
# * parks_nearest
# * ponds_around3000
# * ponds_nearest
# * days_exposition
#
# Последние переменные заполним медианными значениями.

# %% [markdown]
# <div id='question_1'>❓<b>По поводу потолков все же не до конца понял... Если это около 40% от всего объема данных, то можно ли просто выбросить строки с пропусками? Вдруг потеряются важные нюансы или изменятся распределения? 🥺
#
# Просто мне показалось, что оптимальным будет оставить строки, а потом, если окажется, что распределение "испортилось", сравнить его с изначальным.
#
# P.S. У меня на днях отвалилось ядро, и когда я перезагрузил страницу все изменения стерлись. Там я как раз сравнивал распределение выоты потолков после замены с оригинальным, но потом забыл добавить. </b></div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# - Можно ли просто выбросить строки с пропусками?
#
#   Зависит от задачи. Но в целом, вряд ли мы выкинули именно эти наблюдения. Для моделирования мы бы выбросили столбец из данных. Для анализа можно либо оставить пропуски как есть, либо заполнить и проверить распределение, как ты и делал.

# %% [markdown]
# ✍️ <b>Так как высота потолков -- важный параметр, попробуем отбросит все строки, где есть пропуски</b>

# %%
print(df.shape[0])
df.dropna(subset = ['ceiling_height'], inplace=True)
print(df.shape[0])
# Out:
# 23699
# 14504

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                9
# living_area               797
# floor                       0
# is_apartment            12642
# studio                      0
# open_plan                   0
# kitchen_area              940
# balcony                  7247
# locality_name              14
# airports_nearest         2964
# cityCenters_nearest      2944
# parks_around3000         2943
# parks_nearest            9210
# ponds_around3000         2943
# ponds_nearest            8772
# days_exposition          2453
# dtype: int64

# %% [markdown]
# Для того чтобы заполнить данные равномерно, попробуем выявить зависимости для стобцов, представляющих особую важность. Для этого используем функцию, которая ищет строки с наибольшей корреляцией

# %%
def try_corr(my_column, my_df=df):
    temp_dict = {}
    for column in my_df.columns:
        try:
            temp_dict[column] = my_df[my_column].corr(my_df[column])
        except:
            pass 
    return pd.Series(temp_dict).sort_values(ascending=False)

# %% [markdown]
# Первым делом посмотрим на корреляции с высотой потолков:

# %%
try_corr('ceiling_height')
# Out:
# ceiling_height         1.000000
# total_area             0.095490
# living_area            0.090650
# kitchen_area           0.087641
# last_price             0.085430
# ponds_around3000       0.078209
# parks_around3000       0.065915
# rooms                  0.054457
# open_plan              0.042777
# balcony                0.040523
# days_exposition        0.019091
# studio                 0.001674
# total_images          -0.001987
# floor                 -0.011798
# parks_nearest         -0.019167
# airports_nearest      -0.023947
# floors_total          -0.028732
# ponds_nearest         -0.059090
# cityCenters_nearest   -0.091689
# dtype: float64

# %% [markdown]
# Значения корреляции по модулю слишком малы. Придется заполнять пропуски медианами без дифференциации по другим признакам.

# %% [markdown]
# Проделаем ту же операцию для времени представления квартиры на сайте:

# %%
try_corr('days_exposition').head()
# Out:
# days_exposition    1.000000
# total_area         0.159811
# living_area        0.150591
# rooms              0.144097
# kitchen_area       0.113411
# dtype: float64

# %% [markdown]
# Есть небольшая корреляция с количеством комнат. Можно зацепиться за это, чтобы данные были более-менее равномерными. Заполним медианными значениями, сгруппировав по числу комнат:

# %%
df.pivot_table(index='rooms', values='days_exposition', aggfunc=['median', 'count'])
# Out:
#                median           count
#       days_exposition days_exposition
# rooms
# 0                65.0              74
# 1                83.0            4050
# 2                95.0            4074
# 3               125.0            2981
# 4               156.0             607
# 5               255.5             176
# 6               204.0              49
# 7               173.0              25
# 8               115.0               5
# 9               471.0               3
# 10               44.0               2
# 11              813.0               1
# 12              106.0               1
# 14              418.0               1
# 15               14.0               1
# 16             1365.0               1

# %% [markdown]
# Сразу обратим внимание на то, что:
# * квартир с числом комнат больше 5 очень мало - похоже на выбросы
# * есть квартиры с числом комнат 0
# * на небольшом значении количества комнат особенно хорошо видна зависимость

# %% [markdown]
# <b>Отбросим строки, где нет количества этажей:</b>

# %%
print('Пропусков до:', df['floors_total'].isna().sum())
df.dropna(subset = ['floors_total'], inplace = True)
print('Пропусков после:', df['floors_total'].isna().sum())
# Out:
# Пропусков до: 9
# Пропусков после: 0

# %% [markdown]
# <b>Решим вопрос с балконами и апартаментами: </b>

# %%
def bool_fillna(column):
    print('Пропусков до:', df[column].isna().sum())
    df[column] = df[column].fillna(0)
    print('Пропусков после:', df[column].isna().sum())

# %%
bool_fillna('balcony')
# Out:
# Пропусков до: 7240
# Пропусков после: 0

# %%
bool_fillna('is_apartment')
# Out:
# Пропусков до: 12633
# Пропусков после: 0

# %% [markdown]
# <b>Заполним значения медианами:</b>

# %%
columns_na = ['airports_nearest', 
              'cityCenters_nearest', 'parks_around3000', 
              #'living_area', 'kitchen_area',
              'parks_nearest', 'ponds_around3000',
              'ponds_nearest', #'days_exposition'
             ]

# %%
def fill_by_median(column):
    print()
    print('Пропусков "до" в', column, ':', df[column].isna().sum())
    temp_median = df[column].median()
    df[column] = df[column].fillna(temp_median) 
    print('Пропусков "после" в', column, ':', df[column].isna().sum())
    print('_______________________')

# %%
for column in columns_na:
    fill_by_median(column)
# Out:
# Пропусков "до" в airports_nearest : 2963
# Пропусков "после" в airports_nearest : 0
# _______________________
#
# Пропусков "до" в cityCenters_nearest : 2943
# Пропусков "после" в cityCenters_nearest : 0
# _______________________
#
# Пропусков "до" в parks_around3000 : 2942
# Пропусков "после" в parks_around3000 : 0
# _______________________
#
# Пропусков "до" в parks_nearest : 9203
# Пропусков "после" в parks_nearest : 0
# _______________________
#
# Пропусков "до" в ponds_around3000 : 2942
# Пропусков "после" в ponds_around3000 : 0
# _______________________
#
# Пропусков "до" в ponds_nearest : 8769
# Пропусков "после" в ponds_nearest : 0
# _______________________

# %% [markdown]
# <b>Жилая площадь и кухня</b>

# %% [markdown]
# На этом моменте возникает ряд небольших, но все же проблем. Если заполнять площадь кухни и жилую площадь медианами, то может получиться так, что суммарная площадь кухни и жилой площади будет больше общей площади. Попробуем избежать такого исхода.

# %%
df.living_area.corr(df.rooms)
# Out:
# 0.8469884607510505

# %%
def fill_by_rooms_median(column):
    print()
    print('Пропусков "до" в', column, ':', df[column].isna().sum())
    for rooms in df.rooms.unique():
        temp_median = df.loc[df['rooms'] == rooms, column].median()
        df.loc[df['rooms'] == rooms, column] = df.loc[df['rooms'] == rooms, column].fillna(temp_median) 
    print('Пропусков "после" в', column, ':', df[column].isna().sum())
    print('_______________________')

# %%
fill_by_rooms_median('living_area')
fill_by_rooms_median('days_exposition')
# Out:
# Пропусков "до" в living_area : 794
# Пропусков "после" в living_area : 0
# _______________________
#
# Пропусков "до" в days_exposition : 2450
# Пропусков "после" в days_exposition : 0
# _______________________

# %%
def fill_kitchen_area(row):
    return row['total_area'] - row['living_area']

# %%
df.loc[df['kitchen_area'].isna(), 'kitchen_area'] = df[df['kitchen_area'].isna()].apply(fill_kitchen_area, axis=1)

# %%
df.isna().sum()
# Out:
# total_images             0
# last_price               0
# total_area               0
# first_day_exposition     0
# rooms                    0
# ceiling_height           0
# floors_total             0
# living_area              0
# floor                    0
# is_apartment             0
# studio                   0
# open_plan                0
# kitchen_area             0
# balcony                  0
# locality_name           14
# airports_nearest         0
# cityCenters_nearest      0
# parks_around3000         0
# parks_nearest            0
# ponds_around3000         0
# ponds_nearest            0
# days_exposition          0
# dtype: int64

# %% [markdown]
# С пропусками покончено!

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьювера**
#
# Хочется обратить внимание, что с заменой данных нужно быть очень осторожным.
#
# Например, мы не можем просто так взять и заменить пропуски в ceiling_height. У нас отсутствует около 40% данных в данной колонке. Это очень много, и сложно найти веские причины для таких радикальных трансформаций (несмотря на то, что высоты потолков интуитивно предсказуемая переменная).
#
# Такая стратегия удачна для переменных, в которых отсутствует до 10% данных.
#
# Зачем мы вообще проводим EDA? Есть 2 главных причины:
# 1. Мы хотим получить какие-то инсайты о данных (средние значения, минимумы, максимумы и т.д.), чтобы описать, например, среднестатистическую продаваемую квартиру.
# 2. Мы хотим проверить, подходят ли данные для моделирования (смотрим на аномалии, распределения переменных и другие характеристики) — об этом ты узнаешь в будующих уроках :)
#
# Соответственно, мы должны быть очень осторожны с изменением изначальных данных. Твоя логика в работе абсолютно рациональна, но тем не менее объективность данных немного искажается. Чтобы доказать обратное, можно, например, сравнить распределения и ключевые статистики до и после замены.
#
# Это так, на будущее :)

# %% [markdown]
# 👋 На всякий случай помечу, что вопрос по этому комментарию [тут](#question_1)

# %% [markdown]
# ### Изменение типов данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14495 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            14495 non-null int64
# last_price              14495 non-null float64
# total_area              14495 non-null float64
# first_day_exposition    14495 non-null object
# rooms                   14495 non-null int64
# ceiling_height          14495 non-null float64
# floors_total            14495 non-null float64
# living_area             14495 non-null float64
# floor                   14495 non-null int64
# is_apartment            14495 non-null object
# studio                  14495 non-null bool
# open_plan               14495 non-null bool
# kitchen_area            14495 non-null float64
# balcony                 14495 non-null float64
# locality_name           14481 non-null object
# airports_nearest        14495 non-null float64
# cityCenters_nearest     14495 non-null float64
# parks_around3000        14495 non-null float64
# ...

# %% [markdown]
# Переменная is_apartment почему-то представлена типом object. Исправим это

# %%
df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
df.is_apartment.dtype
# Out:
# dtype('bool')

# %% [markdown]
# <b>Далее изменим тип данных в first_day_exposition на дату</b>

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
df['first_day_exposition'].head()
# Out:
# 0    2019-03-07
# 4    2018-06-19
# 9    2017-02-26
# 10   2017-11-16
# 13   2017-07-01
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# <b>Изменим float на int в столбцах, где все числа целые</b>

# %%
to_be_converted = []
for column in df.columns: 
    if df[column].dtype == 'float64':
        result = df[column].sum() - df[column].dropna().astype('int').sum()
        if result == 0:
            to_be_converted.append(column)
        print(column, result)
# Out:
# last_price 0.0
# total_area 3464.6199999999953
# ceiling_height 7808.820000000007
# floors_total 0.0
# living_area 3880.421518999967
# kitchen_area 3765.609992999991
# balcony 0.0
# airports_nearest 0.0
# cityCenters_nearest 0.0
# parks_around3000 0.0
# parks_nearest 0.0
# ponds_around3000 0.0
# ponds_nearest 0.0
# days_exposition 27.5

# %%
for column in to_be_converted:
    df[column] = df[column].astype('int')

# %% [markdown]
# Подозрительно, что есть дробные числа в days_exposition. Проверим эти строки

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьювера**
#
# Нужно пересмотреть стратегию использования медианы. Чтобы избежать подобной проблемы, можно было использовать моду.

# %% [markdown]
# 👋 Соглашусь! Действительно медиана могла испортить. Но вот с модой тоже не так просто, потому что есть би- и многомодальные ряды. Пока не придумал, как с ними быть. Поэтому пока оставил заполнение медианой...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьюера v2**
#
# Я бы вообще не заполняла данный столбец, так как пропуск скорее всего означает, что квартира не продана.

# %%
print('Медиана дискретного ряда')
print(pd.Series([1, 2]).median()) # появляются дробные значения
print()
print('Мода дискретного ряда')
print(pd.Series([1, 2]).mode()) # появился список модальных значений
# Out:
# Медиана дискретного ряда
# 1.5
#
# Мода дискретного ряда
# 0    1
# 1    2
# dtype: int64

# %%
df.query('days_exposition % 1 != 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 13               20     3550000        42.8           2017-07-01      2
# 43               13     9330000        48.0           2017-01-10      2
# 66                6     3450000        34.0           2015-12-16      1
# 69                6     4010000        50.7           2018-09-16      2
# 77                7     4300000        62.1           2016-03-13      3
# ...             ...         ...         ...                  ...    ...
# 23649            19     3000000        73.5           2018-10-19      3
# 23661            19     8100000        75.4           2018-09-19      3
# 23670             9     2450000        45.6           2018-02-08      1
# 23686             8     3300000        31.0           2017-04-29      1
# 23688            19     9200000       101.0           2019-04-01      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Числа выглядят похожими на целые. Посмотрим еще детальнее:

# %%
df.query('days_exposition % 1 != 0').days_exposition % 1
# Out:
# 13       5.684342e-14
# 43       1.136868e-13
# 66       2.842171e-14
# 69       2.842171e-14
# 77       2.842171e-14
#              ...
# 23649    2.842171e-14
# 23661    8.881784e-16
# 23670    7.105427e-15
# 23686    2.842171e-14
# 23688    3.552714e-15
# Name: days_exposition, Length: 2287, dtype: float64

# %%
df.query('days_exposition % 1 != 0').days_exposition % 1 * 10 ** 15
# Out:
# 13        56.843419
# 43       113.686838
# 66        28.421709
# 69        28.421709
# 77        28.421709
#             ...
# 23649     28.421709
# 23661      0.888178
# 23670      7.105427
# 23686     28.421709
# 23688      3.552714
# Name: days_exposition, Length: 2287, dtype: float64

# %% [markdown]
# Сочтем за ошибки в представлении чисел с плавающей запятой и конвертируем значения в целочисленные

# %%
df['days_exposition'] = df['days_exposition'].astype('int')

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest                 int64
# cityCenters_nearest              int64
# parks_around3000                 int64
# parks_nearest                    int64
# ponds_around3000                 int64
# ponds_nearest                    int64
# days_exposition                  int64
# dtype: object

# %% [markdown]
# ### Выводы
#
# В данных было достаточно много пропусков. Некоторые столбцы были заполнены простыми медианами, некоторые - медианами в соответствии с количеством комнат в квартире.
#
# Были преобразованы типы данных: появился столбец с датой, is_apartment стала типом bool, большая часть столбцов стала типом int.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# В целом, предобработка выполнена хорошо 👍🏻

# %% [markdown]
# ## Шаг 3. Посчитайте и добавьте в таблицу

# %% [markdown]
# Что нужно добавить:
# * цену квадратного метра;
# * день недели, месяц и год публикации объявления;
# * этаж квартиры; варианты — первый, последний, другой;
# * соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# Такую цену посчитать очень просто: нужно разделить цену квардтиры на общую площадь. Но прежде проверим, что в значениях нужных нам переменных нет аномалий и выбросов

# %%
def price_per_m(row):
    return row['last_price'] / row['total_area']

# %%
df['price_per_m'] = df.apply(price_per_m, axis=1)
df['price_per_m'].head()
# Out:
# 0     120370.370370
# 4     100000.000000
# 9      88524.590164
# 10    127525.252525
# 13     82943.925234
# Name: price_per_m, dtype: float64

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
df['exp_weekday'] = df['first_day_exposition'].dt.weekday
df['exp_month'] = df['first_day_exposition'].dt.month
df['exp_year'] = df['first_day_exposition'].dt.year

# %%
df.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000       108.0           2019-03-07      3
# 4              2    10000000       100.0           2018-06-19      2
# 9             18     5400000        61.0           2017-02-26      3
# 10             5     5050000        39.6           2017-11-16      1
# 13            20     3550000        42.8           2017-07-01      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16         51.0      8         False  ...
# 4             3.03            14         32.0     13         False  ...
# 9             2.50             9         43.6      7         False  ...
# 10            2.67            12         20.3      3         False  ...
# 13            2.56             5         27.0      5         False  ...
#
#     cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14495 entries, 0 to 23698
# Data columns (total 26 columns):
# total_images            14495 non-null int64
# last_price              14495 non-null int64
# total_area              14495 non-null float64
# first_day_exposition    14495 non-null datetime64[ns]
# rooms                   14495 non-null int64
# ceiling_height          14495 non-null float64
# floors_total            14495 non-null int64
# living_area             14495 non-null float64
# floor                   14495 non-null int64
# is_apartment            14495 non-null bool
# studio                  14495 non-null bool
# open_plan               14495 non-null bool
# kitchen_area            14495 non-null float64
# balcony                 14495 non-null int64
# locality_name           14481 non-null object
# airports_nearest        14495 non-null int64
# cityCenters_nearest     14495 non-null int64
# parks_around3000        14495 non-null int64
# ...

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой

# %%
def floor_cat(row):
    tem_total_floors = row['floors_total']
    temp_floor = row['floor']
    if temp_floor == 1:
        return 'Первый'
    elif temp_floor == tem_total_floors:
        return 'Последний'
    else:
        return 'Другой'

# %%
df['floor_category'] = df.apply(floor_cat, axis=1)

# %%
df['floor_category'].value_counts()
# Out:
# Другой       10584
# Последний     2090
# Первый        1821
# Name: floor_category, dtype: int64

# %% [markdown]
# ### Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
def share_of_living(row):
    return row['living_area'] / row['total_area']

def share_of_kitchen(row):
    return row['kitchen_area'] / row['total_area']

# %%
df['living_share'] = df.apply(share_of_living, axis=1)
df['kitchen_share'] = df.apply(share_of_kitchen, axis=1)

# %%
df.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000       108.0           2019-03-07      3
# 4              2    10000000       100.0           2018-06-19      2
# 9             18     5400000        61.0           2017-02-26      3
# 10             5     5050000        39.6           2017-11-16      1
# 13            20     3550000        42.8           2017-07-01      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16         51.0      8         False  ...
# 4             3.03            14         32.0     13         False  ...
# 9             2.50             9         43.6      7         False  ...
# 10            2.67            12         20.3      3         False  ...
# 13            2.56             5         27.0      5         False  ...
#
#     ponds_around3000  ponds_nearest  days_exposition    price_per_m  \
# ...

# %% [markdown]
# Теперь проверим те самые квартиры, где кухня и жилая площадь в сумме дают значения больше, чем 1.

# %%
df.query('living_share + kitchen_share > 1')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7     2600000       30.20           2018-02-14      1
# 551               8     3100000       31.59           2018-03-08      1
# 601              12     5600000       53.70           2017-04-18      2
# 696               1     3364930       34.69           2014-11-27      1
# 1155             11     7000000       38.00           2019-04-09      1
# 1992              5     4000000       37.40           2018-02-11      1
# 3426              8     4280000       32.51           2019-04-16      1
# 3891              4     2600000       70.40           2017-07-29      3
# 4366             15     5000000       47.70           2018-09-09      2
# 5096             13     3500000       42.00           2019-01-25      1
# 6559             10     4000000       26.00           2017-10-25      1
# 6721             13     6300000       46.90           2017-09-14      2
# ...

# %% [markdown]
# Таких строк всего 73, их можно безболезненно отбросить

# %%
print(df.shape[0])
df = df.query('~(living_share + kitchen_share > 1)')
print(df.shape[0])
# Out:
# 14495
# 14449

# %% [markdown]
# ### Вывод

# %% [markdown]
# Все расчеты проведены, типы данных адекватны, удалены квартиры, где суммарная площадь кухни и жилой площади больше общей площади.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Вычисления выполнены абсолютно верно, молодец 👍🏻

# %% [markdown]
# ## Шаг 4. Проведите исследовательский анализ данных и выполните инструкции:

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# Общая рекомендация для всей работы: ко всем графикам в работе необходимо добавить подписи осей и названия. Бывает так, что нужно скопировать график на слайд без текста, и тогда аудитория не поймет, что изображено :)

# %% [markdown]
# 👋 Добавил! (как мог)

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Супер!

# %% [markdown]
# ### Задание 1
#
# Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %% [markdown]
# Первым делом создадим столбец с ценой в миллионах, чтобы избежать экспоненциального вида

# %%
df.loc[:, 'price_m'] = df['last_price'] / 1000000
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# ✍️ Далее напишим функции, которые помогут изучать данные:

# %%
def show_data(column, my_bins=100, my_df=df):
    my_df.boxplot(column, vert=False, figsize=(20, 2))
    plt.title('Распределение величины ' + str(column), fontdict={'fontsize': 20})
    plt.xlabel('value')
    plt.show()
    my_df.hist(column, figsize=(20, 5), bins=my_bins)
    plt.xlabel(column)
    plt.ylabel('count')
    plt.title('Распределение величины ' + str(column), fontdict={'fontsize': 20})
    plt.show()
    
    
def show_good_data(column, my_bins=100, my_df=df):
    q1 = my_df[column].quantile(0.25)                 
    q3 = my_df[column].quantile(0.75)
    iqr = q3 - q1
    temp_min = q1 - 1.5 * iqr
    temp_max = q3 + 1.5 * iqr
    df_temp = my_df[(my_df[column] <= temp_max) & (my_df[column] >= temp_min)]
    df_temp.boxplot(column, vert=False, figsize=(20, 2))
    plt.title('Распределение величины ' + str(column), fontdict={'fontsize': 20})
    plt.xlabel('value')
    plt.show()
    plt.show()
    df_temp.hist(column, figsize=(20, 5), bins=my_bins)
    plt.xlabel(column)
    plt.ylabel('count')
    plt.title('Распределение величины ' + str(column), fontdict={'fontsize': 20})
    plt.show()
    print('Доля хороших данных', df_temp.shape[0] / df.shape[0])
    return (temp_min, temp_max)

# %% [markdown]
# Сразу же будем удалять выбросы из данных, чтобы потом было проще проводить исследования

# %% [markdown]
# ❓Вот тут хочется все же спросить про удаление выбросов... Не до конца разобрался с этим. Я тако понимаю, нужно руководствоваться по крайней мере такими соображениями:
# 1. Можно посмотреть, что выходит за пределеы усов боксплота
# 2. Нужно произвести проверку "здравым смыслом"
# 3. Можно по гистограмме посмотреть, когда график сильно меняется и значения становятся похожими на "нетипипчные"
#
# В теории вроде все хорошо, но на практике все время возникают сомнения. Нормально, что я аргументирую удаление выбросов тем, что "они лежат вне усов боксплота"? Не всегда же эти выбросы являются действительно нетипичными? Просто так распределение сложилось, что они выбиваются

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Да, это нормально. Точки — это значения, которые выходят за пределы 1.5IQR. IQR — это Квантиль 3(75%-ный) - Квантиль 1(25%-ный).
#
# Выбросы в левой части распределения определяются как Квантиль 1(25%-ный) - 1.5IQR, а выбросы в правой части — Квантиль 3(75%-ный) + 1.5IQR.
#
# Данный метод очень распространен для выявления аномалий.

# %% [markdown]
# <b>Площадь</b>

# %%
df.total_area.describe()
# Out:
# count    14449.000000
# mean        61.927369
# std         37.033616
# min         12.000000
# 25%         41.000000
# 50%         53.400000
# 75%         71.400000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# ✍️ Сразу можно отметить, что минимальное и максимальное значения выглядят подозрительными. Квартира в 12 квадратных метров маловата, а 900 - похоже замок.

# %%
show_data('total_area', my_df=df)

# %% [markdown]
# Посмотрим на распределение "наиболее типичных" данных

# %%
show_good_data('total_area')
# Out:
# Доля хороших данных 0.9451865180981383
# (-4.6000000000000085, 117.00000000000001)

# %% [markdown]
# ✍️Распределение тяготеет к значению на уровне ~30 м. кв. -- наблюдается явный "скос", хотя есть пики на значениях в районе 45 и 60 м.

# %% [markdown]
# ✍️Математически все, что справа от ~120 м -- это выбросы. В целом это звучит даже логично. А вот слева -- вопрос. Здесь уже исходя из здравого смысла поставим нижнюю границу на уровне 25 м. Возможно, что и такое бывает.

# %% [markdown]
# Доля хороших данных достаточно велика, отбросим выбросы

# %%
df = df.query('25 < total_area < 120')
show_data('total_area', my_df=df)

# %% [markdown]
# ✍️ Выглядит достаточно адекватно, пограничные значения близки к нулю. Здесь можно поправить вывод и сказать, что от 30 до 60 м. кв. квартиры распределены почти равномерно. Встречаются пики на отметках в 30 и 45 м. кв. и провал около 50

# %% [markdown]
# <b>Цена</b>

# %%
df.price_m.describe()
# Out:
# count    13607.000000
# mean         5.587845
# std          3.536836
# min          0.012190
# 25%          3.500000
# 50%          4.700000
# 75%          6.550000
# max         53.000000
# Name: price_m, dtype: float64

# %%
show_data('price_m')

# %%
show_good_data('price_m')
# Out:
# Доля хороших данных 0.9650180054383773
# (-1.5750000000000006, 12.145)

# %% [markdown]
# ✍️ Аналогично рассуждениям из предыдущего пункта выставим в качетсве границ хорошего распределения 1 и 12 миллионов.
#
# Распределение достаточно симметрично, хотя и имеет длинный хвост справа. Тяготеет оно к значению в 4 млн руб.

# %% [markdown]
# Доля хороших данных достаточно велика, отбросим выбросы

# %%
df = df.query('1 < price_m < 12')
show_data('price_m', my_df=df)

# %% [markdown]
# <b>Число комнат</b>

# %%
df.rooms.describe()
# Out:
# count    12807.000000
# mean         1.984305
# std          0.900476
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Подозрительно, что есть квартиры с нулевым числом комнта. Проверим эти данные

# %%
df.query('rooms == 0').shape[0]
# Out:
# 51

# %%
df.query('rooms == 0')['total_area'].describe()
# Out:
# count    51.000000
# mean     30.768039
# std       8.020794
# min      25.700000
# 25%      27.300000
# 50%      28.000000
# 75%      31.000000
# max      71.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Значения общей площади распределены почти как в целом по данным, поэтому лучше отбросим такие программы

# %% [markdown]
# Таких квартир всего 51. Возможно, имелось в виду, что комната одна, но возможно и нет. Мы можем позволить себе удалить их, чтобы не они не портили данные.

# %%
df = df.query('~(rooms == 0)')

# %%
df.rooms.describe()
# Out:
# count    12756.000000
# mean         1.992239
# std          0.893473
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %%
show_data('rooms', 20, my_df=df)

# %% [markdown]
# ✍️ Итак, число комнат -- величина дискретная. Значения лежат в интервале от 1 до 6, выбросов не наблюдается. Больше всего квартир с двумя комнатами, но с одной - почти столько же

# %%
df = df.query('rooms < 7')
show_data('rooms', 20, my_df=df)

# %% [markdown]
# <b>Высота потолков</b>

# %%
df.ceiling_height.describe()
# Out:
# count    12756.000000
# mean         2.723232
# std          0.945633
# min          1.000000
# 25%          2.500000
# 50%          2.600000
# 75%          2.750000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
show_data('ceiling_height')

# %%
show_good_data('ceiling_height', 40)
# Out:
# Доля хороших данных 1.0685951708999686
# (2.0749999999999997, 3.235)

# %% [markdown]
# ✍️Согласно данным из открытых источников, потолки должны быть более 245 см. Найдем оптимальную верхнюю границу.

# %%
show_data('ceiling_height', 40, my_df=df.query('2.45 < ceiling_height <= 3.5'))

# %% [markdown]
# ✍️ За отметкой в 3.2 м. значения уже слишком малы, поэтому возьмем ее в качестве правой границы.

# %%
df = df.query('2.45 < ceiling_height <= 3.2')
show_data('ceiling_height', 40, df)

# %% [markdown]
# ✍️ Распределение выглядит рваным. Но это легко объяснить тем, что квартиры обычно имеют схожие планы, поэтому несмотря на то что в теории величена может быть непрерывной, по факту значения ближе к дискретным. Отсюда и рваность

# %% [markdown]
# #### Выводы

# %% [markdown]
# Во всех исследованных параметрах наблюдались длинные хвосты, часто с обеих сторон. Мы сразу отбросили выбивающиеся значения. Выделялись распределения комнат и высоты потолков: команты - дискретная величина, а высота потолков - типичное значение, которое редко принимает уникальные значения.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Супер 👍🏻
#
# Стоит всегда обрабатывать аномалии, чтобы не искажать статистические показатели :)

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# Необходимо также кратко описать распределения. Дополни, пожалуйста, анализ :)

# %% [markdown]
# 👋 Попытался 🙂

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Отлично 👍🏻

# %% [markdown]
# ### Задание 2
#
# Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
df.days_exposition.describe()
# Out:
# count    12287.000000
# mean       168.215187
# std        202.344728
# min          1.000000
# 25%         47.000000
# 50%         95.000000
# 75%        194.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
show_data('days_exposition', 150)

# %%
show_good_data('days_exposition', 150)
# Out:
# Доля хороших данных 1.0575404899487264
# (-176.5, 435.5)

# %% [markdown]
# Данные тоже несколько подозрительны, посмотрим референсные значения

# %%
df_ref = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
show_good_data('days_exposition', 150, df_ref)
# Out:
# Доля хороших данных 1.5340603890290552
# (-235.5, 512.5)

# %% [markdown]
# Подозрительные пики были и раньше, просто появились новые после заполнения медианами

# %% [markdown]
# ✍️Данные распределены так, что нельзя однозначно говорить о слишком коротких продажах. 0 дней является достаточно типичным значением для распределения. При этом распределение можно отнести к распределениям Пуассона.
#
# Можно сказать, что "слишком долгие" -- это те, что превышают значение в 400 дней, т.к. они лежат за пределами усов боксплота, а на гистограмме виден хоть и небольшой, но все же спад после значения в 400 дней.

# %%
show_data('days_exposition', 50, df_ref.query('300 < days_exposition < 500'))

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# И когда можно считать продажи долгими?)

# %% [markdown]
# 👋 Будем считать, что после 400 дней ожидания 🙃

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# 👍🏻

# %% [markdown]
# ### Задание 3
#
# Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %%
df = df.query('days_exposition < 400')
show_data('days_exposition', 100)

# %% [markdown]
# ### Задание 4
#
# Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
try_corr('last_price')
# Out:
# last_price             1.000000
# price_per_m            0.724727
# total_area             0.712926
# living_area            0.603892
# kitchen_area           0.433283
# rooms                  0.401467
# parks_around3000       0.226201
# ponds_around3000       0.221278
# total_images           0.117722
# days_exposition        0.085656
# ceiling_height         0.085435
# floor                  0.037542
# is_apartment           0.023022
# open_plan              0.004622
# exp_month              0.004584
# floors_total           0.003355
# parks_nearest         -0.006716
# balcony               -0.006841
# airports_nearest      -0.013795
# exp_weekday           -0.015634
# kitchen_share         -0.021098
# studio                -0.025209
# living_share          -0.042526
# exp_year              -0.055643
# ponds_nearest         -0.102737
# cityCenters_nearest   -0.210198
# dtype: float64

# %% [markdown]
# Наиболее сильное влияние на цену оказывают такие параметры, как цена квардатного метра, общая площадь (которая во многом определяет и жилую) и площадь кухни.
#
# Меньше влияют количество парков в округе и удаленность от центра (влияение отрицательно)

# %% [markdown]
# ✍️ <b>Визуализируем данные о корреляции параметров</b>

# %%
pd.plotting.scatter_matrix(df[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']] , figsize=(12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feda2e95d90>,
# ...
#       dtype=object)

# %% [markdown]
# ✍️ Из матрицы видно, что самое явное и очевидное влияние (из предложенных в задании факторов) на цену оказывает общая площадь.

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# Помимо матрицы корреляций также нужно отобразить взаимосвязи графически. Добавь, пожалуйста,недостающие визуализации :)

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Замечательно 👍🏻

# %% [markdown]
# 👋 Вроде бы готово

# %%
df.pivot_table(index='floor_category', values='price_m', aggfunc=['mean', 'median']).plot(kind='bar', grid=True, figsize=(20, 6))
plt.ylim(bottom=3.6)
# Out:
# (3.6, 5.381359064319277)

# %% [markdown]
# В среднем квартиры на последнем этаже дороже, чем на первом. Но на других этажах квартиры дороже. Это можно объяснить тем, что квартир на "дригих" этажах больше, поэтому и шанс того, что встретятся дорогие квартиры, больше.

# %% [markdown]
# ✍️ <b>Посмотрим на зависимость цены от даты появления объявления</b>

# %%
def log_comparison(index_scale):
    (df
     .pivot_table(index=index_scale, values='price_m', aggfunc=['mean', 'median'])
     .plot(kind='bar', figsize=(20, 4), grid=True, logy=True))
    plt.xlabel(index_scale)
    plt.ylabel('Цена')
    plt.title('Цена в зависимости от ' + str(index_scale), fontdict={'fontsize': 20})

# %%
log_comparison('exp_weekday')

# %% [markdown]
# Какой-то особой зависимости не наблюдается :(

# %%
log_comparison('exp_month')

# %% [markdown]
# Тут можно заметить, что в апрелее цена квартир оказывается больше, чем в остальные месяцы, а в инюне - меньше 🙃

# %%
log_comparison('exp_year')

# %% [markdown]
# Здесь же очевидно, что цена недвижимости в 2014 году в среднем была явно больше, чем в последующие. Однако в 2019 цена снова стала подрастать

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# Давай также рассмотрим месяц и год размещения объявления :)

# %% [markdown]
# 👋 Готово!

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Супер, теперь анализ максимально полный 👍🏻

# %% [markdown]
# ### Задание 5

# %% [markdown]
# Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.

# %%
index_list = (df
              .pivot_table(index='locality_name', values='price_m', aggfunc='count')
              .sort_values(by='price_m', ascending=False)
              .head(10)
              .index)
index_list
# Out:
# Index(['Санкт-Петербург', 'Всеволожск', 'посёлок Шушары', 'Колпино', 'Пушкин',
#        'посёлок Мурино', 'посёлок Парголово', 'Гатчина', 'Петергоф',
#        'деревня Кудрово'],
#       dtype='object', name='locality_name')

# %%
df_locality = df.query('locality_name in @index_list')

# %%
def plot_pivot(column):
    temp_pivot = df_locality.pivot_table(index='locality_name', values=column, aggfunc=['mean', 'median'])
    temp_pivot.columns = ['median', 'mean']
    (temp_pivot
     .sort_values(by='median', ascending=False)
     .plot(kind='bar', figsize=(10, 4), grid=True))
    return temp_pivot.sort_values(by='median', ascending=False)

# %%
plot_pivot('price_per_m')
# Out:
#                           median           mean
# locality_name
# Санкт-Петербург    105994.577078  102464.192733
# Пушкин             100123.421614   98536.692510
# посёлок Парголово   90795.929867   91040.462428
# деревня Кудрово     90760.944684   90208.333333
# посёлок Мурино      87554.656459   85878.462169
# Петергоф            84211.227525   82474.226804
# посёлок Шушары      79512.817882   77753.779698
# Колпино             75657.509590   74210.730033
# Гатчина             70269.631179   69488.341059
# Всеволожск          67142.754375   65482.828283

# %%
plot_pivot('price_m')
# Out:
#                      median    mean
# locality_name
# Санкт-Петербург    5.644361  5.1500
# Пушкин             5.147796  4.8700
# посёлок Парголово  4.512724  4.2000
# деревня Кудрово    4.399916  4.0780
# посёлок Шушары     4.285373  4.0900
# Петергоф           4.051426  3.6000
# посёлок Мурино     3.993073  3.6700
# Колпино            3.907382  3.7250
# Всеволожск         3.835904  3.5995
# Гатчина            3.562620  3.3250

# %% [markdown]
# Итак, самая дороогая недвижимость в Питере, а дешевая - в Выборге

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Все верно!

# %% [markdown]
# ### Задание 6

# %% [markdown]
# Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %%
df_spb = df.query('locality_name == "Санкт-Петербург"').reset_index()

# %%
df_spb.cityCenters_nearest.head()
# Out:
# 0     8098
# 1    15008
# 2    13878
# 3    10698
# 4    10842
# Name: cityCenters_nearest, dtype: int64

# %%
df_spb.loc[:, 'center_km'] = (df_spb.loc[:, 'cityCenters_nearest'] / 1000).astype('int')

# %% [markdown]
# ❓Вот здесь он выдает очень неприятного вида ошибку (на всякий случай прикрепляю скрин) http://joxi.ru/DmBb187Tg6gnKm 🤕
#
# Я уже везде где можно было поменял на .loc, но ничего не меняется. Не подскажешь, как быть?

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюерам v2**
#
# Можно использовать reset.index( ), так как он создает новый датафрейм, а не копию. Добавила в код в ячейку 90.

# %%
df_spb.center_km.head()
# Out:
# 0     8
# 1    15
# 2    13
# 3    10
# 4    10
# Name: center_km, dtype: int64

# %%
df_spb.pivot_table(index='center_km', values='price_m', aggfunc=['mean', 'median']).plot(kind='bar', figsize=(20, 4), grid=True)
plt.ylim(bottom=2)
# Out:
# (2, 8.4)

# %%
(df_spb
 .pivot_table(index='center_km', values='price_m', aggfunc=['mean', 'median'])
 .plot(kind='line', figsize=(20, 4), grid=True))
plt.ylim(bottom=2)
#plt.yscale('log')
# Out:
# (2, 8.2775)

# %% [markdown]
# График изменился после 7-го километра. Будем считать, что до 8 км - центральный район.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера**
#
# Да, центр находится именно в найденных тобой пределах 👍🏻

# %% [markdown]
# ### Задание 7

# %% [markdown]
# Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %%
def box_compare(column):
    df_spb.query('center_km < 8').boxplot(column, figsize=(10, 4), vert=False, positions = [1])
    df_spb.boxplot(column, figsize=(10, 4), vert=False, positions = [0])

# %%
def hist_compare(column):
    df_spb.query('center_km < 8').hist(column)
    plt.show
    df_spb.hist(column)

# %%
box_compare('total_area')

# %% [markdown]
# Площадь квартир в центре больше

# %%
box_compare('price_m')

# %% [markdown]
# Цена тоже значительно выше

# %%
box_compare('rooms')

# %% [markdown]
# А вот количество комнат очень похоже, правда в центре нет шестикомнатных квартир. На всякий случай сравним гистограммы

# %%
hist_compare('rooms')

# %% [markdown]
# Оказывается, в центре намного меньше однокомнатных квартир. А вот вне центра однокомнатных квартир больше всего.

# %%
df_spb.query('center_km < 8').hist('ceiling_height')
plt.show
df_spb.hist('ceiling_height')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed93fe99d0>]],
#       dtype=object)

# %% [markdown]
# А вот высота потолков почти не отличается.

# %% [markdown]
# Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).

# %% [markdown]
# <div class="alert alert-danger">
#
# **Комментарий ревьюера**
#
# В данном пункте анализ также необходимо дополнить графиками зависимостей :)

# %% [markdown]
# 👋 Вроде готово 🥲

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Исследовательский анализ данных — это в первую очередь графический метод :)

# %%
try_corr('last_price', my_df=df_spb.query('center_km < 8'))
# Out:
# last_price             1.000000
# price_m                1.000000
# total_area             0.688985
# living_area            0.550942
# rooms                  0.471898
# kitchen_area           0.372135
# price_per_m            0.274954
# ceiling_height         0.249792
# total_images           0.138501
# days_exposition        0.117417
# floor                  0.114311
# floors_total           0.077720
# exp_year               0.053564
# parks_around3000       0.051172
# ponds_around3000       0.041683
# living_share           0.041553
# balcony                0.040396
# parks_nearest          0.035064
# index                  0.034979
# airports_nearest      -0.007567
# ponds_nearest         -0.015405
# open_plan             -0.025987
# is_apartment          -0.027494
# exp_month             -0.031221
# studio                -0.041053
# exp_weekday           -0.043691
# kitchen_share         -0.053711
# center_km             -0.199076
# cityCenters_nearest   -0.206469
# ...

# %%
try_corr('last_price', my_df=df_spb.query('center_km < 8'))[['rooms', 'floor', 'cityCenters_nearest', 'exp_year']]
# Out:
# rooms                  0.471898
# floor                  0.114311
# cityCenters_nearest   -0.206469
# exp_year               0.053564
# dtype: float64

# %% [markdown]
# ✍️<b>Визуализируем эти показатели</b>

# %%
(pd.plotting.scatter_matrix(
    df_spb.query('center_km < 8')[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']], 
 figsize=(12, 12))
)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed93f20ed0>,
# ...
#       dtype=object)

# %% [markdown]
# Этаж и дата размещения объявления почти не влияют на цену. А вот число комнат и близость от центра - влияют. При этом зависимость между ценой и числом комнат положительна, а с удаленностью от центра - отрицательна. Это логично: чем больше комнат, тем дороже, а чем дальше от центра, тем дешевле.

# %% [markdown]
# Данный корреялции несколько отличаются от данных по всей выборке. Намного меньшее влияние играет цена квадратного метра. Видимо, по-другому распределена общая площадь квартир. Меньше стало влиять количество парков вокруг, а вот общая площадь по прежнему влияет.

# %% [markdown]
# ❓<b>Вопрос общего характера </b>
#
# С каждым шагом данных становится меньше и меньше 🥲
# В итоге их осталось меньше половины. Я понимаю, что 10000 это все еще достаточно большая цифра, и вряд ли данные сильно "испортились". Но действительно ли нормально так смело выкидывать все не понравившиеся данные?
#
# P.S. На этапе удаления я пытался найти критические точки, чтобы не было длинных хвостов, но и чтобы доля выбросов была не очень большой, но не особо спасло

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьюера v2**
#
# Да, такое бывает. Но в жизни мы не просто выкидываем данные, а сохраняем их в отдельныйе датафреймы и анализируем. Поэтому никакие инсайты не теряются :)

# %%
print(df_ref.shape)
print(df.shape)
# Out:
# (23699, 22)
# (10986, 30)

# %% [markdown]
# ## Шаг 5. Общий вывод

# %% [markdown]
# <b>Шаг 1.</b>
# В базе встречается три типа данных: целочисленные, дробные, булевы и строки.
# <b>Шаг 2.</b>
# В целом по данным блыо очень много пропусков. Они могли быть вызваны разными причинам:
# 1. Многие из них заполнялись автоматически
# 2. Другие (balcony, is_apartment) могут означать отсутствие признакю
# 3. living_area может быть пропущено потому, что его не посчитали нужным заполнять, введя данные о площаде кухни
# 4. Наиболее подозрительными считаются пропуски в days_exposition, потому что за заполнение этого параметра отвечает непосредственно система
#
# Большая часть пропусков была заполнена медианными значениями, некоторые особенно важные -- медианами, в соотвтетсвии с коррелирующими параметрами, например, в соответствии с количеством комнат в квартире.
#
# Были преобразованы типы данных: появился столбец с датой, is_apartment стала типом bool, большая часть столбцов стала типом int.
#
# <b>Шаг 3. </b>
# Добавили в таблицу:
# 1. цену квадратного метра;
# 2. день недели, месяц и год публикации объявления;
# 3. этаж квартиры; варианты — первый, последний, другой;
# 4. соотношение жилой и общей площади, а также отношение площади кухни к общей.
# Все расчеты проведены, типы данных адекватны, удалены квартиры, где суммарная площадь кухни и жилой площади больше общей площади.
#
# <b>Шаг 4. </b>
# Все параметры изучены, отброшены хвосты и нетипичные значения.
#
# Данные распределены так, что нельзя однозначно говорить о слишком коротких продажах. А вот о слишком долгих - можно.
#
# Наиболее сильное влияние на цену оказывают такие параметры, как цена квардатного метра, общая площадь (которая во многом определяет и жилую) и площадь кухни.
#
# Меньше влияют количество парков в округе и удаленность от центра (влияение отрицательно)
#
# В среднем квартиры на последнем этаже дороже, чем на первом. Но на других этажах квартиры дороже. Это можно объяснить тем, что квартир на "дригих" этажах больше, поэтому и шанс того, что встретятся дорогие квартиры, больше.
# Какой-то особой зависимости с днем недели публикации объявления не наблюдается
#
# Среди 10 самых часто встречаемых населенных пунктов самая дороогая недвижимость в Питере, а дешевая - в Выборге
#
# Данные по центру Петербурга несклько отличаются от остальных по городу и по выборке вообще. Намного меньшее влияние играет цена квадратного метра. Видимо, по-другому распределена общая площадь квартир. Меньше стало влиять количество парков вокруг, а вот общая площадь по прежнему влияет.
# Этаж и дата размещения объявления почти не влияют на цену. А вот число комнат и близость от центра - влияют. При этом зависимость между ценой и числом комнат положительна, а с удаленностью от центра - отрицательна. Это логично: чем больше комнат, тем дороже, а чем дальше от центра, тем дешевле.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <h3>Чек-лист доработок </h3>
#
# Чтобы сделать работу идеальной, прошу тебя проработать следующие моменты:
#
# 1. **Добавить подписи и заголовки ко всем графикам.**
# 2. **Добавить недостающие графики и комментарии.**
#
# Жду твой проект на повторное ревью, осталось совсем чуть-чуть. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится 🙂
# </div>
